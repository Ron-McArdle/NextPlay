# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data3.csv')

# %%
df
# Out:
#       Unnamed: 0  Unnamed: 0.1  steam_appid  \
# 0              0             0        730.0
# 1              1             1        570.0
# 2              2             2     578080.0
# 3              3             3    1172470.0
# 4              4             4    1446780.0
# ...          ...           ...          ...
# 2914        2962          2962     316790.0
# 2915        2963          2963    1349230.0
# 2916        2964          2964    1639430.0
# 2917        2965          2965    1314140.0
# 2918        2966          2966     792660.0
#
#                                              categories      genres  \
# 0     ['Multi-player', 'Steam Achievements', 'Full c...      Action
# 1     ['Multi-player', 'Co-op', 'Steam Trading Cards...      Action
# 2     ['Multi-player', 'PvP', 'Online PvP', 'Stats',...      Action
# 3     ['Multi-player', 'PvP', 'Online PvP', 'Co-op',...      Action
# 4     ['Single-player', 'Multi-player', 'Co-op', 'On...      Action
# ...

# %%
df2 = pd.read_csv('Steam Trends 2023 by @evlko and @Sadari - Games Data.csv')
df2
# Out:
#         App ID                             Title  Reviews Total  \
# 0          730  Counter-Strike: Global Offensive        7382695
# 1       578080               PUBG: BATTLEGROUNDS        2201296
# 2          570                            Dota 2        2017009
# 3       271590                Grand Theft Auto V        1322782
# 4       359550   Tom Clancy's Rainbow Six® Siege         978762
# ...        ...                               ...            ...
# 65106  1634660                             fight              0
# 65107  1391060                BarbarianAdventure              0
# 65108  1340860                         灰烬行星与填鸭少女              0
# 65109  1306150                     space shooter              0
# 65110  1223240                              快乐小鸡              0
#
#       Reviews Score Fancy Release Date  Reviews D7  Reviews D30  Reviews D90  \
# 0                     88%   2012-08-21         NaN          NaN          NaN
# ...

# %%
df2 = df2.drop(columns=['Reviews Total', 'Release Date', 'Reviews D7', 'Reviews D30', 'Reviews D90', 'Revenue Estimated', 'Launch Price', 'name_slug', 'Modified Tags', 'Reviews Score Fancy'])
df2
# Out:
#         App ID                             Title  \
# 0          730  Counter-Strike: Global Offensive
# 1       578080               PUBG: BATTLEGROUNDS
# 2          570                            Dota 2
# 3       271590                Grand Theft Auto V
# 4       359550   Tom Clancy's Rainbow Six® Siege
# ...        ...                               ...
# 65106  1634660                             fight
# 65107  1391060                BarbarianAdventure
# 65108  1340860                         灰烬行星与填鸭少女
# 65109  1306150                     space shooter
# 65110  1223240                              快乐小鸡
#
#                                                     Tags  \
# 0      FPS, Shooter, Multiplayer, Competitive, Action...
# 1      Survival, Shooter, Battle Royale, Multiplayer,...
# 2      Free to Play, MOBA, Multiplayer, Strategy, eSp...
# 3      Open World, Action, Multiplayer, Crime, Automo...
# 4      FPS, PvP, eSports, Shooter, Multiplayer, Tacti...
# ...

# %%
df2 = df2.rename(columns={'App ID': 'steam_appid'})
df2
# Out:
#        steam_appid                             Title  \
# 0              730  Counter-Strike: Global Offensive
# 1           578080               PUBG: BATTLEGROUNDS
# 2              570                            Dota 2
# 3           271590                Grand Theft Auto V
# 4           359550   Tom Clancy's Rainbow Six® Siege
# ...            ...                               ...
# 65106      1634660                             fight
# 65107      1391060                BarbarianAdventure
# 65108      1340860                         灰烬行星与填鸭少女
# 65109      1306150                     space shooter
# 65110      1223240                              快乐小鸡
#
#                                                     Tags  \
# 0      FPS, Shooter, Multiplayer, Competitive, Action...
# 1      Survival, Shooter, Battle Royale, Multiplayer,...
# 2      Free to Play, MOBA, Multiplayer, Strategy, eSp...
# 3      Open World, Action, Multiplayer, Crime, Automo...
# ...

# %%
df1 = pd.merge(df, df2, on='steam_appid', how='left')
df1
# Out:
#       Unnamed: 0  Unnamed: 0.1  steam_appid  \
# 0              0             0        730.0
# 1              1             1        570.0
# 2              2             2     578080.0
# 3              3             3    1172470.0
# 4              4             4    1446780.0
# ...          ...           ...          ...
# 2914        2962          2962     316790.0
# 2915        2963          2963    1349230.0
# 2916        2964          2964    1639430.0
# 2917        2965          2965    1314140.0
# 2918        2966          2966     792660.0
#
#                                              categories      genres  \
# 0     ['Multi-player', 'Steam Achievements', 'Full c...      Action
# 1     ['Multi-player', 'Co-op', 'Steam Trading Cards...      Action
# 2     ['Multi-player', 'PvP', 'Online PvP', 'Stats',...      Action
# 3     ['Multi-player', 'PvP', 'Online PvP', 'Co-op',...      Action
# 4     ['Single-player', 'Multi-player', 'Co-op', 'On...      Action
# ...

# %%
df1 = df1.drop(columns=['Title'])
df1
# Out:
#       Unnamed: 0  Unnamed: 0.1  steam_appid  \
# 0              0             0        730.0
# 1              1             1        570.0
# 2              2             2     578080.0
# 3              3             3    1172470.0
# 4              4             4    1446780.0
# ...          ...           ...          ...
# 2914        2962          2962     316790.0
# 2915        2963          2963    1349230.0
# 2916        2964          2964    1639430.0
# 2917        2965          2965    1314140.0
# 2918        2966          2966     792660.0
#
#                                              categories      genres  \
# 0     ['Multi-player', 'Steam Achievements', 'Full c...      Action
# 1     ['Multi-player', 'Co-op', 'Steam Trading Cards...      Action
# 2     ['Multi-player', 'PvP', 'Online PvP', 'Stats',...      Action
# 3     ['Multi-player', 'PvP', 'Online PvP', 'Co-op',...      Action
# 4     ['Single-player', 'Multi-player', 'Co-op', 'On...      Action
# ...

# %%
df1.to_csv('data3.csv')

# %%
df = pd.read_csv('data3.csv')

# %%
df
# Out:
#       Unnamed: 0.2  Unnamed: 0  Unnamed: 0.1  steam_appid  \
# 0                0           0             0          730
# 1                1           1             1          570
# 2                2           2             2       578080
# 3                3           3             3      1172470
# 4                4           4             4      1446780
# ...            ...         ...           ...          ...
# 2914          2914        2962          2962       316790
# 2915          2915        2963          2963      1349230
# 2916          2916        2964          2964      1639430
# 2917          2917        2965          2965      1314140
# 2918          2918        2966          2966       792660
#
#                                              categories      genres  \
# 0     ['Multi-player', 'Steam Achievements', 'Full c...      Action
# 1     ['Multi-player', 'Co-op', 'Steam Trading Cards...      Action
# ...
